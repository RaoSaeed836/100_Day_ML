# %% [markdown]
# <a href="https://colab.research.google.com/github/RaoSaeed836/100_Day_ML/blob/main/Linear_regression_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from word2number import w2n
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-217-298328724.py in <cell line: 0>()
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from word2number import w2n
#
# ModuleNotFoundError: No module named 'word2number'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df=pd.read_csv("/content/homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(df['area'],df['price'])
plt.xlabel('area')
plt.ylabel('priece')
# Out:
# Text(0, 0.5, 'priece')

# %%
are=pd.read_csv("/content/areas.csv")
are
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
xare=df.drop(columns=['price'])
yare=df['price']

# %%
model=LinearRegression()

# %%
model.fit(xare,yare)
# Out:
# LinearRegression()

# %%
model.predict([[3500]])
# Out:
# array([655873.28767123])

# %%
ty=model.predict(are)

# %%
are['gvf']=ty

# %%
are
# Out:
#     area           gvf
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
are.to_csv("predictioin.csv")

# %% [markdown]
# ### Exercise

# %%
df=pd.read_csv("/content/canada_per_capita_income(simple linear).csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
x=df.drop(columns=['per capita income (US$)'])
y=df['per capita income (US$)']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=89)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([28277.64667362,  2444.38076177, 12444.35466313, 29110.97783207,
#         9944.36118779, 11611.02350469, 16611.01045537, 22444.32856449,
#        36610.95825809,  7444.36771245,  1611.04960333, 23277.65972294,
#        33277.6336243 ,  8277.6988709 , 25777.65319828])

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([28277.64667362,  2444.38076177, 12444.35466313, 29110.97783207,
#         9944.36118779, 11611.02350469, 16611.01045537, 22444.32856449,
#        36610.95825809,  7444.36771245,  1611.04960333, 23277.65972294,
#        33277.6336243 ,  8277.6988709 , 25777.65319828])

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",root_mean_squared_error(y_test,y_pred))
print("R2_SCORE",r2_score(y_test,y_pred))
# Out:
# MAE 2614.5278901782663
# MSE 12679571.08607504
# RMSE 3560.8385369284915
# R2_SCORE 0.8980575705941792

# %% [markdown]
# ###MULTI_VARIABLE_LINEAR_RERESSION

# %%
df=pd.read_csv("/content/homeprices (for multi variable).csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
import math
df.bedrooms.median()
# Out:
# 4.0

# %%
df.bedrooms=df.bedrooms.fillna(df.bedrooms.median())

# %%
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
x=df.drop(columns=['price'])
y=df['price']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=89)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([412187.5 , 925468.75])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",root_mean_squared_error(y_test,y_pred))
print("R2_SCORE",r2_score(y_test,y_pred))
# Out:
# MAE 126640.62499999983
# MSE 16162658691.406208
# RMSE 127132.44547087973
# R2_SCORE 0.04362966323040185

# %%
model.predict([[3000,4,40]])
# Out:
# array([775937.5])

# %% [markdown]
# ###Exercise

# %%
d=pd.read_csv("/content/hiring.csv")
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d['test_score(out of 10)']=d['test_score(out of 10)'].fillna(d['test_score(out of 10)'].mean())

# %%
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN               8.000000                           9      50000
# 1        NaN               8.000000                           6      45000
# 2       five               6.000000                           7      60000
# 3        two              10.000000                          10      65000
# 4      seven               9.000000                           6      70000
# 5      three               7.000000                          10      62000
# 6        ten               7.857143                           7      72000
# 7     eleven               7.000000                           8      80000

# %%
d['experience']=d['experience'].fillna(d['experience'].mode())

# %%
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0     eleven               8.000000                           9      50000
# 1       five               8.000000                           6      45000
# 2       five               6.000000                           7      60000
# 3        two              10.000000                          10      65000
# 4      seven               9.000000                           6      70000
# 5      three               7.000000                          10      62000
# 6        ten               7.857143                           7      72000
# 7     eleven               7.000000                           8      80000

# %%
x=d.drop(columns=['salary($)'])
y=d['salary($)']

# %%
y
# Out:
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000
# Name: salary($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
y_train
# Out:
# 5    62000
# 2    60000
# 1    45000
# 0    50000
# 6    72000
# 3    65000
# Name: salary($), dtype: int64

# %%
ohe
# Out:
# OneHotEncoder(drop='first', dtype=<class 'numpy.int32'>,
#               handle_unknown='ignore')

# %%
X_train_scaled=ohe.transform(X_train)
X_test_scaled=ohe.transform(X_test)

# %%
model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)
# 7     eleven                    7.0                           8
# 4      seven                    9.0                           6
# 5      three                    7.0                          10

# %%
y_pred=model.predict(X_test_scaled)
y_pred
# Out:
# array([58769.23076923, 58769.23076923, 60846.15384615])

# %%
model.predict([[2,9,6]])

# %%
y_test
# Out:
# 7    80000
# 4    70000
# 5    62000
# Name: salary($), dtype: int64

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",root_mean_squared_error(y_test,y_pred))
print("R2_SCORE",r2_score(y_test,y_pred))
# Out:
# MAE 11205.128205128209
# MSE 192735700.1972387
# RMSE 13882.928372545855
# R2_SCORE -2.5545518478998948

# %%
d.experience = d.experience.apply(w2n.word_to_num)
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-215-1244936164.py in <cell line: 0>()
# ----> 1 d.experience = d.experience.apply(w2n.word_to_num)
#       2 d
#
# NameError: name 'w2n' is not defined

# %%
from word2number import w2n
d.experience = d.experience.apply(w2n.word_to_num)
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0          11               8.000000                           9      50000
# 1           5               8.000000                           6      45000
# 2           5               6.000000                           7      60000
# 3           2              10.000000                          10      65000
# 4           7               9.000000                           6      70000
# 5           3               7.000000                          10      62000
# 6          10               7.857143                           7      72000
# 7          11               7.000000                           8      80000

# %%
# !pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=7979c3b3031f0a159ec431848429f7461ad707d4984eb0707e641a553b50c821
#   Stored in directory: /root/.cache/pip/wheels/cd/ef/ae/073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# ...
