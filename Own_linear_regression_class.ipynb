# %% [markdown]
# <a href="https://colab.research.google.com/github/RaoSaeed836/100_Day_ML/blob/main/Own_linear_regression_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Meralr:
  def __init__(self):
   self.m=None
   self.b=None
  def fit(self,X_train,y_train):
    num=0
    dum=0

    for i in range(X_train.shape[0]):
          num=num + ((X_train.shape[i] - X_train.mean())*(y_train.shape[i]- y_train.mean()))
          dum=dum + ((X_train.shape[i] - X_train.mean())*(X_train.shape[i] - X_train.mean()))
          self.m=num/dum
          self.b=y_train.mean()-(self.m* X_train.mean())
  def predict(self,X_test):
           return self.m* X_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
x=df.iloc[:,0]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=67)

# %%
X_train.shape
# Out:
# (80,)

# %%
m=Meralr()

# %%
m.fit(X_train,y_train)
